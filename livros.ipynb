# %%
import re
import html
from pathlib import Path
from bs4 import BeautifulSoup
import json
from sqlalchemy.orm import Session, sessionmaker
from lib.db.database import engine

# %%
SessionLocal = sessionmaker(
    bind=engine,
    autoflush=False,
    autocommit=False
)
session = SessionLocal()

# %%
from lib.parser.lattes.livros import extrai_livros, parser_livros


id_lattes = '2747150211073176'
livros = extrai_livros(id_lattes)

# %%
with open('data/curriculos/2747150211073176/livros.jsonl', 'w', encoding='utf-8') as f:
    for livro in livros:
        f.write(json.dumps(livro, ensure_ascii=False) + '\n')

# %%
livros = []
with open('data/curriculos/2747150211073176/livros.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        livros.append(json.loads(line))

# %%
livro = livros[0]
publication = {
        'publication_type': 'book',
        'title': livro.get('titulo'),
        'date_published': livro.get('ano'),
        'doi': livro.get('doi'),
        'publisher': livro.get('editora'),
        'volume_number': livro.get('volume'),
        'edition': livro.get('edicao'),
        'number_of_pages':livro.get('paginas'),
        'source': 'lattes'
        }
publication
# Out:
# {'publication_type': 'book',
#  'title': 'Micropláticos: um problema complexo e urgente',
#  'date_published': 2025,
#  'doi': None,
#  'publisher': 'Editora ABC',
#  'volume_number': 1,
#  'edition': 1,
#  'number_of_pages': 26,
#  'source': 'lattes'}

# %%
from lib.db.crud.publication import get_or_create_publication


publication_db = get_or_create_publication(session, publication)
# Out:
# 2026-04-26 17:12:14,036 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-26 17:12:14,037 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-26 17:12:14,043 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-26 17:12:14,045 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-26 17:12:14,047 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-26 17:12:14,048 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-26 17:12:14,051 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-26 17:12:14,061 INFO sqlalchemy.engine.Engine SELECT publications.id AS publications_id, publications.publication_type AS publications_publication_type, publications.title AS publications_title, publications.subtitle AS publications_subtitle, publications.alternative_title AS publications_alternative_title, publications.abstract AS publications_abstract, publications.date_published AS publications_date_published, publications.language AS publications_language, publications.subject AS publications_subject, publications.doi AS publications_doi, publications.isbn AS publications_isbn, publications.identifier AS publications_identifier, publications.publisher AS publications_publisher, publications.url AS publications_url, publications.license AS publications_license, publications.conditions_of_access AS publications_conditions_of_access, publications.is_accessible_for_free AS publications_is_accessible_for_free, publications.is_part_of_id AS publications_is_part_of_id, publications.page_start AS publications_page_start, publications.page_end AS publications_page_end, publications.volume_number AS publications_volume_number, publications.issue_number AS publications_issue_number, publications.edition AS publications_edition, publications.number_of_pages AS publications_number_of_pages, publications.in_support_of AS publications_in_support_of, publications.source_organization AS publications_source_organization, publications.source AS publications_source, publications.raw_json AS publications_raw_json, publications.created_at AS publications_created_at, publications.updated_at AS publications_updated_at, publications.needs_review AS publications_needs_review
# FROM publications
# WHERE publications.title = %(title_1)s
#  LIMIT %(param_1)s
# 2026-04-26 17:12:14,062 INFO sqlalchemy.engine.Engine [generated in 0.00147s] {'title_1': 'Micropláticos: um problema complexo e urgente', 'param_1': 1}
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'publications.needs_review' in 'SELECT'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 4
#       1 from lib.db.crud.publication import get_or_create_publication
# ----> 4 publication_db = get_or_create_publication(session, publication)
#
# File ~/orbis/lib/db/crud/publication.py:20, in get_or_create_publication(session, publication)
#      17         return publi_doi
#      19 title = publication["title"]
# ---> 20 publi_title = session.query(Publication).filter_by(title=title).first()
#      22 if publi_title:
#      23     print(f"Titulo já existe: {doi} - {title}")
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2759, in Query.first(self)
#    2757     return self._iter().first()  # type: ignore
#    2758 else:
# -> 2759     return self.limit(1)._iter().first()
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2857, in Query._iter(self)
#    2854 params = self._params
#    2856 statement = self._statement_20()
# -> 2857 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2858     statement,
#    2859     params,
#    2860     execution_options={"_sa_orm_load_options": self.load_options},
#    2861 )
#    2863 # legacy: automatically set scalars, unique
#    2864 if result._attributes.get("is_single_entity", False):
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2291 def execute(
#    2292     self,
#    2293     statement: Executable,
#    (...)
#    2299     _add_event: Optional[Any] = None,
#    2300 ) -> Result[Any]:
#    2301     r"""Execute a SQL expression construct.
#    2302
#    2303     Returns a :class:`_engine.Result` object representing
#    (...)
#    2349
#    2350     """
# -> 2351     return self._execute_internal(
#    2352         statement,
#    2353         params,
#    2354         execution_options=execution_options,
#    2355         bind_arguments=bind_arguments,
#    2356         _parent_execute_state=_parent_execute_state,
#    2357         _add_event=_add_event,
#    2358     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2249, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2244     return conn.scalar(
#    2245         statement, params or {}, execution_options=execution_options
#    2246     )
#    2248 if compile_state_cls:
# -> 2249     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2250         self,
#    2251         statement,
#    2252         params or {},
#    2253         execution_options,
#    2254         bind_arguments,
#    2255         conn,
#    2256     )
#    2257 else:
#    2258     result = conn.execute(
#    2259         statement, params or {}, execution_options=execution_options
#    2260     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/orm/context.py:306, in AbstractORMCompileState.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#     296 @classmethod
#     297 def orm_execute_statement(
#     298     cls,
#    (...)
#     304     conn,
#     305 ) -> Result:
# --> 306     result = conn.execute(
#     307         statement, params or {}, execution_options=execution_options
#     308     )
#     309     return cls.orm_setup_cursor_result(
#     310         session,
#     311         statement,
#    (...)
#     315         result,
#     316     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)
#    1660         ret,
#    1661     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/orbis/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/orbis/.venv/lib/python3.10/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'publications.needs_review' in 'SELECT'")
# [SQL: SELECT publications.id AS publications_id, publications.publication_type AS publications_publication_type, publications.title AS publications_title, publications.subtitle AS publications_subtitle, publications.alternative_title AS publications_alternative_title, publications.abstract AS publications_abstract, publications.date_published AS publications_date_published, publications.language AS publications_language, publications.subject AS publications_subject, publications.doi AS publications_doi, publications.isbn AS publications_isbn, publications.identifier AS publications_identifier, publications.publisher AS publications_publisher, publications.url AS publications_url, publications.license AS publications_license, publications.conditions_of_access AS publications_conditions_of_access, publications.is_accessible_for_free AS publications_is_accessible_for_free, publications.is_part_of_id AS publications_is_part_of_id, publications.page_start AS publications_page_start, publications.page_end AS publications_page_end, publications.volume_number AS publications_volume_number, publications.issue_number AS publications_issue_number, publications.edition AS publications_edition, publications.number_of_pages AS publications_number_of_pages, publications.in_support_of AS publications_in_support_of, publications.source_organization AS publications_source_organization, publications.source AS publications_source, publications.raw_json AS publications_raw_json, publications.created_at AS publications_created_at, publications.updated_at AS publications_updated_at, publications.needs_review AS publications_needs_review
# FROM publications
# WHERE publications.title = %(title_1)s
#  LIMIT %(param_1)s]
# [parameters: {'title_1': 'Micropláticos: um problema complexo e urgente', 'param_1': 1}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
for livro in livros:
    publications = {
        'publication_type': 'book',
        'title': livro.get('titulo'),
        'date_published': livro.get('ano'),
        'doi': livro.get('doi'),
        'publisher': livro.get('editora'),
        'volume_number': livro.get('volume'),
        'edition': livro.get('edicao'),
        'number_of_pages':livro.get('paginas'),
        'source': 'lattes'
        }
    print(livro.get('paginas'))
